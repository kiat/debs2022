# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_json('evals.json')

# %%
df.head()
# Out:
#            benchmarkId  consumers  \
# 0  6445237014050734000          4
# 1  6228436344855340000          8
# 2  1619572463597370600         12
# 3  3341907533043770400         16
# 4  3592461873604799500          4
#
#                                    percentileResults  producers  q1Throughput  \
# 0  [{'percentile': 50, 'q1Latency': 246415359, 'q...          1    128.921550
# 1  [{'percentile': 50, 'q1Latency': 237502463, 'q...          1    134.254950
# 2  [{'percentile': 50, 'q1Latency': 258998271, 'q...          1    122.478263
# 3  [{'percentile': 50, 'q1Latency': 268042239, 'q...          1    118.333712
# 4  [{'percentile': 50, 'q1Latency': 235274239, 'q...          2    135.052473
#
#    q1_90Percentile  q1_count  q2Throughput  q2_90Percentile  q2_count  \
# 0       265.945087       993    128.791720       270.532607       992
# 1       249.167871       993    134.119748       251.527167       992
# 2       275.513343       993    122.354921       277.872639       992
# ...

# %%
df = df.drop(['percentileResults'], axis=1)
df.head()
